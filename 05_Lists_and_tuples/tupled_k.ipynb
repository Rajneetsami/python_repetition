# %% [markdown]
# # tuples

# %%
mixed_tuples = ("banan", 12, 3.14, True)
mixed_tuples
# Out:
# ('banan', 12, 3.14, True)

# %%
mixed_tuples[1]
# Out:
# 12

# %%
mixed_tuples[:3]
# Out:
# ('banan', 12, 3.14)

# %%
mixed_tuple[1] = 5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mixed_tuple[1] = 5
#
# NameError: name 'mixed_tuple' is not defined

# %%
coordinates = ([1,2], [2,5])
coordinates
# Out:
# ([1, 2], [2, 5])

# %%
coordinates[0][0] = 50

# %%
coordinates
# Out:
# ([50, 2], [2, 5])

# %% [markdown]
# ## tuple unpacking

# %%
x,y,z = (1,2,3)
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
z
# Out:
# 3

# %%
x,y = y,x
print(f"{x = }, {y = }")
# Out:
# x = 2, y = 1
