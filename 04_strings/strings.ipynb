# %% [markdown]
# # strings

# %%
firstname = "Rajneet"
lastname = "Kaur"

fullname = firstname + " " + lastname
fullname
# Out:
# 'Rajneet Kaur'

# %%
work = "data engineer"
address = "Stockholm"
phone = "12345678"

contact_details = f"""name: {fullname}
work: {work}
address: {address}
phone : {phone}"""

print(contact_details)
# Out:
# name: Rajneet Kaur
# work: data engineer
# address: Stockholm
# phone : 12345678

# %%
menu = ["chiili con carne", " noodeles", "pasta", "pizza", "spring roll"]
days = ["mo", "tu", "wed", "thu", "fri"]

weekly_menu = "weekly menu\n"

for day, food in zip(days, menu):
    weekly_menu += f"{day:<10} {food}\n" # < → left-align the text, 10 → use 10 characters of space

print (weekly_menu)
# Out:
# weekly menu
# mo         chiili con carne
# tu          noodeles
# wed        pasta
# thu        pizza
# fri        spring roll

# %%
quote = "! False - it's funny because it's True"
quote
# Out:
# "! False - it's funny because it's True"

# %%
quote [0]
quote [-1]
quote [:6]
quote [::-1]
# Out:
# '! Fals'

# %%
string_to_check = "Anna"
string_to_check[::-1] == string_to_check #palindrom
# Out:
# False

# %% [markdown]
# ## split and cleaning string

# %%
subjects = "Math, biology , cHeMistry , PrOgramming    "

subjects = subjects.split(",")

#[subject.strip() for subject in subjects]
for i in range(len(subjects)):
    subjects[i] = subjects[i].strip().upper()

print(subjects)
# Out:
# ['MATH', 'BIOLOGY', 'CHEMISTRY', 'PROGRAMMING']

# %%
for subject in subjects:
    print(f"{subject} has {len(subject)} charcters")
# Out:
# MATH has 4 charcters
# BIOLOGY has 7 charcters
# CHEMISTRY has 9 charcters
# PROGRAMMING has 11 charcters

# %% [markdown]
# # regex

# %%
import re

text = "Det var en gång en katt som tog på sig en hatt"
match_list =re.findall(r".att", text)
match_list
# Out:
# ['katt', 'hatt']

# %%
personal_numbers = "Ida: 19950516-2235, Berit: 19581212-3213, Ada: 050524-1513" 
match_long = re.findall(r"\d{8}-\d{4}",personal_numbers)
match_long
# Out:
# ['19950516-2235', '19581212-3213']

# %%
match_short = re.findall(r"\d{6}-\d{4}",personal_numbers)
match_short
# Out:
# ['950516-2235', '581212-3213', '050524-1513']
