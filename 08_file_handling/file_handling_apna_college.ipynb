# %% [markdown]
# ## file handling
#
# python can be used to operations on a file. (read & write data)
#
# All types of file:
# 1. Text Files : .txt, .docx, .log etc.
# 2. Binary Files: .mp4, .mov, .png, .jpeg etc.
#
# f = open ("file_name", "mode) # two parameter (file name, mode (r(read) or w (write)))

# %%
f = open("demo.txt", "r")
f.read()
#f.read(5) # efter read it will give you nothing beacuse it will put cursor at the end
#f.readline()

f.close()
# Out:
# '\nthen i will move to ReactJS'

# %%
f = open("demo.txt", "w")

f.write("\nthen i will move to ReactJS")

f.close()

# %%
f = open("sample.txt", "a")
f.write("then i will be focusing on java script")

f.close()

# %%
with open("demo.txt", "r") as f:
    data = f.read()
    print(data)

with open("demo.txt", "w") as f:
    f.write("new data")
# Out:
# then i will move to ReactJS

# %%
f = open("demo.txt", "r+")
f.write("abc")
print(f.read())
f.close()
# Out:
#  data

# %%
f = open("demo.txt", "w+")
print(f.read())
f.write("abc")
f.close
# Out:
# abc
# 3

# %%
f = open("demo.txt", "a+")
print(f.read())
f.write("abc")
f.close
# Out:
# abc
# <function TextIOWrapper.close()>

# %% [markdown]
# deleting a file: using the os module, module is a file written by another programmer that generally has a function
#
# import os
#
# os.remove(filename)

# %%
import os

os.remove("sample.txt")

# %%
# create a new file "practice.txt" using python. add the following data in it:
# Hi everyone
# we are learning File I/O
# using Java
# I like programmin in Javascript

with open ("practice.txt", "w") as f:
    data = f. write("Hi everyone \nwe are learning File I/O \nusing Java \nI like programming in Java.")
    print(data)
# Out:
# 78

# %%
# waf that repalce all occurence of "Java" with "python" in the above file.

with open("practice.txt", "r+") as f:
    data = f.read()

new_data = data.replace("Java", "python")
print(new_data)
# Out:
# Hi everyone
# we are learning File I/O
# using python
# I like programming in python.

# %%
# search if the word "learning" exists in the file or not

def check_for_word():
    word = "love"
    with open("practice.txt", "r") as f:
        data = f.read()
        if(data.find(word) != -1):
            print("Found")
        else:
            print("Not found")

check_for_word()
# Out:
# Not found

# %%
# WAF to find in which line of the file does the word "learning" occur first. print -1 if word not found

def check_for_line():
    
    word = "love"
    data = "True"
    line_no = 1
    with open("practice.txt", "r") as f:
        while data:
            data = f.readline()
            if(word in data):
                print(line_no)
                return
            line_no+=1

    return -1

print(check_for_line())
# Out:
# -1

# %%
# from a file containing numbers separated by comma, print the count of even numbers.

with open("practice.txt", "r") as f:
    data = f.read()
    #print(data)
    
    num = ""
    
    for i in range(len(data)):
        if (data[i] == ","):
            print(int(num))
            num = ""
        else:
            num += data[i]
# Out:
# 1
# 2
# 76
# 84
# 90

# %%
count = 0

with open("practice.txt", "r") as f:
    data = f.read()
    #print(data)
    
nums = data.split(",")

for val in nums:
    if(int(val)% 2== 0):
        count+=1

print(count)
# Out:
# 4
